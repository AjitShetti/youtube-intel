# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

# Set styling
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Data
#
# Load the raw comments from the data directory.

# %%
# Load data
data_path = Path('../data/raw')

# TODO: Load your comment data here
# df = pd.read_csv(data_path / 'comments.csv')
# print(f'Loaded {len(df)} comments')
# print(df.head())

# %% [markdown]
# ## 2. Data Overview
#
# Get basic statistics about the dataset.

# %%
# Display basic info
# print(f'Dataset shape: {df.shape}')
# print(f'\nMissing values:\n{df.isnull().sum()}')
# print(f'\nData types:\n{df.dtypes}')

# %% [markdown]
# ## 3. Text Analysis
#
# Analyze comment text length and characteristics.

# %%
# Analyze text length
# df['text_length'] = df['comment_text'].str.len()
# df['word_count'] = df['comment_text'].str.split().str.len()

# print(f'Average comment length: {df["text_length"].mean():.0f} characters')
# print(f'Average word count: {df["word_count"].mean():.0f} words')

# %% [markdown]
# ## 4. Visualizations
#
# Create visualizations for key metrics.

# %%
# Visualize comment length distribution
# fig = px.histogram(df, x='text_length', nbins=50, title='Distribution of Comment Lengths')
# fig.show()

# %% [markdown]
# ## 5. Engagement Metrics
#
# Analyze likes, replies, and other engagement metrics.

# %%
# TODO: Add engagement analysis
# print(df[['likes', 'replies']].describe())
