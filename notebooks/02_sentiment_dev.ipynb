# %%
import pandas as pd
import numpy as np
from transformers import pipeline
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# ## 1. Load Cleaned Comments
#
# Load preprocessed comments from the cleaned data directory.

# %%
# Load cleaned data
data_path = Path('../data/cleaned')

# TODO: Load your cleaned comment data
# df = pd.read_csv(data_path / 'comments_cleaned.csv')
# print(f'Loaded {len(df)} comments')

# %% [markdown]
# ## 2. Initialize Sentiment Model
#
# Load a pre-trained sentiment analysis model.

# %%
# Initialize sentiment classifier
# classifier = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')
# print('Model loaded successfully')

# %% [markdown]
# ## 3. Apply Sentiment Analysis
#
# Run sentiment analysis on sample comments.

# %%
# Apply sentiment analysis to sample
# sample = df['comment_text'].head(100)
# results = []
# 
# for text in sample:
#     try:
#         result = classifier(text[:512])  # Truncate to 512 chars
#         results.append(result[0])
#     except Exception as e:
#         print(f'Error: {e}')
# 
# sentiment_df = pd.DataFrame(results)
# print(sentiment_df.head())

# %% [markdown]
# ## 4. Sentiment Distribution
#
# Visualize sentiment distribution.

# %%
# Plot sentiment distribution
# sentiment_counts = sentiment_df['label'].value_counts()
# sentiment_counts.plot(kind='bar', title='Sentiment Distribution')
# plt.ylabel('Count')
# plt.xlabel('Sentiment')
# plt.show()

# %% [markdown]
# ## 5. Model Evaluation
#
# Evaluate sentiment model performance (if ground truth available).

# %%
# TODO: Add evaluation metrics if you have labeled data
# print(classification_report(y_true, y_pred))

# %% [markdown]
# ## 6. Save Results
#
# Save sentiment analysis results.

# %%
# Save sentiment results
# output_path = Path('../data/cleaned')
# output_path.mkdir(parents=True, exist_ok=True)
# sentiment_df.to_csv(output_path / 'comments_sentiment.csv', index=False)
# print('Sentiment analysis results saved')
