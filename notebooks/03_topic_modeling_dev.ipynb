# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ## 1. Load Data
#
# Load cleaned comments for topic modeling.

# %%
# Load cleaned data
data_path = Path('../data/cleaned')

# TODO: Load your cleaned comment data
# df = pd.read_csv(data_path / 'comments_cleaned.csv')
# documents = df['comment_text'].tolist()
# print(f'Loaded {len(documents)} documents for topic modeling')

# %% [markdown]
# ## 2. Initialize BERTopic Model
#
# Set up and configure BERTopic for topic discovery.

# %%
# Initialize BERTopic model
# topic_model = BERTopic(
#     language='english',
#     nr_topics=10,
#     min_topic_size=5,
#     calculate_probabilities=True
# )
# print('BERTopic model initialized')

# %% [markdown]
# ## 3. Fit Topic Model
#
# Train the topic model on the documents.

# %%
# Fit the model (this may take a while)
# topics, probs = topic_model.fit_transform(documents)
# print(f'Found {len(set(topics))} topics')

# %% [markdown]
# ## 4. Topic Analysis
#
# Analyze discovered topics.

# %%
# Get topic information
# topics_info = topic_model.get_topic_info()
# print(topics_info.head(10))

# %% [markdown]
# ## 5. Visualizations
#
# Create interactive visualizations of topics.

# %%
# Visualize topics
# fig = topic_model.visualize_topics()
# fig.show()

# %% [markdown]
# ## 6. Topic Distribution
#
# Analyze how topics are distributed across documents.

# %%
# Plot topic distribution
# topic_counts = pd.Series(topics).value_counts().sort_index()
# topic_counts.plot(kind='bar', title='Topic Distribution Across Documents')
# plt.xlabel('Topic ID')
# plt.ylabel('Document Count')
# plt.show()

# %% [markdown]
# ## 7. Save Model
#
# Save the trained model for later use.

# %%
# Save the model
# output_path = Path('../models')
# output_path.mkdir(parents=True, exist_ok=True)
# topic_model.save(str(output_path / 'bertopic_model'))
# print('Model saved successfully')
